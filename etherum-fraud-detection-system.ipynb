# %% [markdown]
# <a href="https://www.kaggle.com/code/sondosaabed/etherum-fraud-detection-system?scriptVersionId=184947080" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# ## Etherum Fraud Detection System

# %%
import numpy as np 
import pandas as pd 
import os

# %%
df = pd.read_csv("/kaggle/input/ethereum-frauddetection-dataset/transaction_dataset.csv")

# %%
df.sample(3).T
# Out:
#                                                                                           6052  \
# Unnamed: 0                                                                                6052
# Index                                                                                     3120
# Address                                             0xa1e7cb81256b3e556561b5af414ca5e8603855fd
# FLAG                                                                                         0
# Avg min between sent tnx                                                              18141.61
# Avg min between received tnx                                                            597.22
# Time Diff between first and last (Mins)                                              512742.87
# Sent tnx                                                                                    28
# Received Tnx                                                                                 8
# ...

# %%
df.shape
# Out:
# (9841, 51)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9841 entries, 0 to 9840
# Data columns (total 51 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   Unnamed: 0                                            9841 non-null   int64
#  1   Index                                                 9841 non-null   int64
#  2   Address                                               9841 non-null   object
#  3   FLAG                                                  9841 non-null   int64
#  4   Avg min between sent tnx                              9841 non-null   float64
#  5   Avg min between received tnx                          9841 non-null   float64
#  6   Time Diff between first and last (Mins)               9841 non-null   float64
#  7   Sent tnx                                              9841 non-null   int64
# ...

# %%
df.describe().T
# Out:
#                                                      count          mean  \
# Unnamed: 0                                          9841.0  4.920000e+03
# Index                                               9841.0  1.815050e+03
# FLAG                                                9841.0  2.214206e-01
# Avg min between sent tnx                            9841.0  5.086879e+03
# Avg min between received tnx                        9841.0  8.004851e+03
# Time Diff between first and last (Mins)             9841.0  2.183333e+05
# Sent tnx                                            9841.0  1.159317e+02
# Received Tnx                                        9841.0  1.637009e+02
# Number of Created Contracts                         9841.0  3.729702e+00
# Unique Received From Addresses                      9841.0  3.036094e+01
# Unique Sent To Addresses                            9841.0  2.584016e+01
# min value received                                  9841.0  4.384515e+01
# ...

# %%
df.isna().sum()
# Out:
# Unnamed: 0                                                 0
# Index                                                      0
# Address                                                    0
# FLAG                                                       0
# Avg min between sent tnx                                   0
# Avg min between received tnx                               0
# Time Diff between first and last (Mins)                    0
# Sent tnx                                                   0
# Received Tnx                                               0
# Number of Created Contracts                                0
# Unique Received From Addresses                             0
# Unique Sent To Addresses                                   0
# min value received                                         0
# max value received                                         0
# avg val received                                           0
# ...

# %%
df.duplicated(subset=['Index']).sum()
# Out:
# 5112
